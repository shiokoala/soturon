# %%
import simulation_settings as ss
import ship as ship
import constants
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as patches
import glob
import driver
import time

# %%
    
df = pd.read_csv('T2.8_H0.3_F18.8.csv')

# %%
df
# Out:
#          time       posx      posz      velx      velz      accx       accz  \
# 0       0.000   0.000002  0.184990  0.001872 -0.010482  1.871985 -10.482296
# 1       0.001   0.000006  0.184969  0.003732 -0.020820  1.859910 -10.337368
# 2       0.002   0.000011  0.184938  0.005587 -0.031058  1.855015 -10.238178
# 3       0.003   0.000019  0.184896  0.007437 -0.041193  1.849607 -10.135210
# 4       0.004   0.000028  0.184845  0.009279 -0.051226  1.841994 -10.032755
# 5       0.005   0.000039  0.184784  0.011114 -0.061152  1.835640  -9.926649
# 6       0.006   0.000052  0.184713  0.012947 -0.070971  1.832733  -9.818223
# 7       0.007   0.000067  0.184632  0.014769 -0.080676  1.822213  -9.705200
# 8       0.008   0.000083  0.184542  0.016585 -0.090269  1.815857  -9.592696
# 9       0.009   0.000102  0.184442  0.018397 -0.099747  1.812289  -9.478244
# 10      0.010   0.000122  0.184333  0.020205 -0.109108  1.808088  -9.361454
# ...
