# %%
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
df=pd.read_csv("rao.csv")

Fn = df['Fn']
omega = df['ω_e[rad/s]']

Fx = df['Fx[N/cm]']
Fy = df['Fy[N/cm]']
Fz = df['Fz[N/cm]']
Mx = df['Mx[N/cm]']
My = df['My[N/cm]']
Mz = df['Mz[N/cm]']
Fx_p = df['Fx[deg]']
Fy_p = df['Fy[deg]']
Fz_p = df['Fz[deg]']
Mx_p = df['Mx[deg]']
My_p = df['My[deg]']
Mz_p = df['Mz[deg]']

# %%
df1=pd.read_csv("Fx.csv",header=-1) #fnq= 41 oq=61  df1[fnq][oq]
df3=pd.read_csv("Fz.csv",header=-1)
df5=pd.read_csv("My.csv",header=-1)
matrixList=[df1,df3,df5]

# %%
# plt.subplot(131)
# plt.axes().set_aspect('equal')
# plt.imshow(df1,interpolation=None, extent=[0,1,0,15])

fig, (ax1, ax3, ax5) = plt.subplots(ncols=3, figsize=(10,10))

ax1.imshow(df1, extent=[0,1,0,15], aspect=0.05)
ax1.set_title('Fx')

ax3.imshow(df3, extent=[0,1,0,15], aspect=0.05)
ax3.set_title('Fz')

ax5.imshow(df5, extent=[0,1,0,15], aspect=0.05)
ax5.set_title('My')

plt.tight_layout()
plt.show()

# %%
def calcFn(u,L):
    return u/math.sqrt(9.8*L)

# %%
Fn=1. #index=12
round(Fn/(1./40))
# Out:
# 40

# %%
omega=5. #index=20
round(omega/(1./4))
# Out:
# 20

# %%
def calcF(axis,Fn,omega):
    fni = round(Fn/(1./40)) #0~40 
    omi = round(omega/(1./4)) #0~60
    print(fni)
    print(omi)
    j = round((axis-1)/2)
    coeff =  matrixList[j][fni][omi]*100 #N/cm -> N/m
    poffset= 0#phase offset
    output = coeff*math.sin(omega*t + k*x + self.phase + poffset)

# %%
import driver

# %%
shapes = np.array([
            [6,4],
            [4,4],
            [4,1]])
dd = driver.Driver(shapes)

# %%
for i in range(dd.num_layers):
    dd.params[i]=np.random.random_sample(dd.params[i].shape)

# %%
dd.params
# Out:
# [array([[0.28290374, 0.80585766, 0.70841145, 0.68412622],
#         [0.945607  , 0.44096572, 0.84877385, 0.33098558],
#         [0.54831983, 0.88686822, 0.89216024, 0.79486852],
#         [0.34347102, 0.88599838, 0.66862093, 0.29945461],
#         [0.24769737, 0.18063726, 0.14342031, 0.62784953],
#         [0.83970315, 0.98864139, 0.04240955, 0.71915375]]),
#  array([[0.88772753, 0.5413011 , 0.94122769, 0.91448855],
#         [0.1890202 , 0.48076166, 0.3567297 , 0.43787992],
#         [0.50229535, 0.72292487, 0.56446352, 0.03326314],
#         [0.99921227, 0.48204397, 0.59818404, 0.01676405]]),
#  array([[0.36344701],
#         [0.06938849],
#         [0.75519676],
#         [0.7357336 ]])]

# %%
dd.params[2]

input_array = np.array([1,2,3,4,5,6])
out = dd.output(input_array)
# Out:
# None
# 0
# [11.46966708 14.7274219   8.72848249 12.38269149]
# [11.46966708 14.7274219   8.72848249 12.38269149]
# 1
# [29.72293289 25.56796199 28.38331541 17.43564224]
# [29.72293289 25.56796199 28.38331541 17.43564224]
# 2
# [46.83980915]

# %%
out
# Out:
# 0

# %%
print(input_array.shape)
temp1 = np.matmul(input_array,dd.params)
temp2 = np.matmul(temp1,layer2)
temp3 = np.matmul(temp2,layer3)
temp3
# Out:
# (6,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2449a4ac9dee> in <module>
#       1 print(input_array.shape)
# ----> 2 temp1 = np.matmul(input_array,dd.params)
#       3 temp2 = np.matmul(temp1,layer2)
#       4 temp3 = np.matmul(temp2,layer3)
#       5 temp3
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 6)

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
shapes.shape[0]
# Out:
# 4
