# %%
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
df=pd.read_csv("rao.csv")

Fn = df['Fn']
omega = df['ω_e[rad/s]']

Fx = df['Fx[N/cm]']
Fy = df['Fy[N/cm]']
Fz = df['Fz[N/cm]']
Mx = df['Mx[N/cm]']
My = df['My[N/cm]']
Mz = df['Mz[N/cm]']
Fx_p = df['Fx[deg]']
Fy_p = df['Fy[deg]']
Fz_p = df['Fz[deg]']
Mx_p = df['Mx[deg]']
My_p = df['My[deg]']
Mz_p = df['Mz[deg]']

# %%
df1=pd.read_csv("Fx.csv",header=-1) #fnq= 41 oq=61  df1[fnq][oq]
df3=pd.read_csv("Fz.csv",header=-1)
df5=pd.read_csv("My.csv",header=-1)
matrixList=[df1,df3,df5]

# %%
# plt.subplot(131)
# plt.axes().set_aspect('equal')
# plt.imshow(df1,interpolation=None, extent=[0,1,0,15])

fig, (ax1, ax3, ax5) = plt.subplots(ncols=3, figsize=(10,10))

ax1.imshow(df1, extent=[0,1,0,15], aspect=0.05)
ax1.set_title('Fx')

ax3.imshow(df3, extent=[0,1,0,15], aspect=0.05)
ax3.set_title('Fz')

ax5.imshow(df5, extent=[0,1,0,15], aspect=0.05)
ax5.set_title('My')

plt.tight_layout()
plt.show()

# %%
def calcFn(u,L):
    return u/math.sqrt(9.8*L)

# %%
Fn=1. #index=12
round(Fn/(1./40))
# Out:
# 40

# %%
omega=5. #index=20
round(omega/(1./4))
# Out:
# 20

# %%
def calcF(axis,Fn,omega):
    fni = round(Fn/(1./40)) #0~40 
    omi = round(omega/(1./4)) #0~60
    print(fni)
    print(omi)
    j = round((axis-1)/2)
    coeff =  matrixList[j][fni][omi]*100 #N/cm -> N/m
    poffset= 0#phase offset
    output = coeff*math.sin(omega*t + k*x + self.phase + poffset)

# %%
calcF(5,0.3,5)
# Out:
# 12
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5e085c951b4a> in <module>()
# ----> 1 calcF(5,0.3,5)
#
# <ipython-input-30-07afab44165c> in calcF(axis, Fn, omega)
#       7     coeff =  matrixList[j][fni][omi]*100 #N/cm -> N/m
#       8     poffset= 0#phase offset
# ----> 9     output = coeff*math.sin(self.omega*t + self.k*x + self.phase + poffset)
#
# NameError: name 'self' is not defined
