# %%
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
df_forces   =pd.read_csv("ANALYSIS_forces_180.csv")
df_am       =pd.read_csv("ANALYSIS_addedmass.csv")
df_damp     =pd.read_csv("ANALYSIS_damping.csv")
df_rao      = pd.read_csv("ANALYSIS_rao.csv")

omega = df_forces['Freq']

# Fx = df_forces['Fx[N]']
# Fy = df_forces['Fy[N]']
# Fz = df_forces['Fz[N]']
# Mx = df_forces['Mx[N]']
# My = df_forces['My[N]']
# Mz = df_forces['Mz[N]']
# Fx_p = df_forces['Fx[deg]']
# Fy_p = df_forces['Fy[deg]']
# Fz_p = df_forces['Fz[deg]']
# Mx_p = df_forces['Mx[deg]']
# My_p = df_forces['My[deg]']
# Mz_p = df_forces['Mz[deg]']

Fx = df_rao['Fx[N]']
Fy = df_rao['Fy[N]']
Fz = df_rao['Fz[N]']
Mx = df_rao['Mx[N]']
My = df_rao['My[N]']
Mz = df_rao['Mz[N]']
Fx_p = df_rao['Fx[deg]']
Fy_p = df_rao['Fy[deg]']
Fz_p = df_rao['Fz[deg]']
Mx_p = df_rao['Mx[deg]']
My_p = df_rao['My[deg]']
Mz_p = df_rao['Mz[deg]']

# %%
ax = plt.subplot()
ax.plot(omega,Fx)
ax.plot(omega,Fz)
ax.set_xlabel('Omega[rad/s]')
# ax.set_ylabel('Froude-Krylov + Diffraction Force[N]')
ax.set_ylabel('RAO')
ax.set_facecolor('white')
ax.legend()

# %%
df1=pd.read_csv("Fx.csv",header=-1) #fnq= 41 oq=61  df1[fnq][oq]
df3=pd.read_csv("Fz.csv",header=-1)
df5=pd.read_csv("My.csv",header=-1)
matrixList=[df1,df3,df5]

# %%
# plt.subplot(131)
# plt.axes().set_aspect('equal')
# plt.imshow(df1,interpolation=None, extent=[0,1,0,15])

fig, (ax1, ax3, ax5) = plt.subplots(ncols=3, figsize=(15, 4))

fig.suptitle('DTU Catamaran Hydrodynamic Force Interpolated/Extrapolated')

ax1.imshow(df1, extent=[0,1,0,15], aspect=0.05)
ax1.set_title('Fx')
ax1.set_xlabel('Fn')
ax1.set_ylabel('omega_e')

ax3.imshow(df3, extent=[0,1,0,15], aspect=0.05)
ax3.set_title('Fz')
ax3.set_xlabel('Fn')
ax3.set_ylabel('omega_e')

ax5.imshow(df5, extent=[0,1,0,15], aspect=0.05)
ax5.set_title('My')
ax5.set_xlabel('Fn')
ax5.set_ylabel('omega_e')

# plt.tight_layout()
plt.show()

# %%
def calcFn(u,L):
    return u/math.sqrt(9.8*L)

# %%
Fn=1. #index=12
round(Fn/(1./40))
# Out:
# 40

# %%
omega=5. #index=20
round(omega/(1./4))
# Out:
# 20

# %%
def calcF(axis,Fn,omega):
    fni = round(Fn/(1./40)) #0~40 
    omi = round(omega/(1./4)) #0~60
    print(fni)
    print(omi)
    j = round((axis-1)/2)
    coeff =  matrixList[j][fni][omi]*100 #N/cm -> N/m
    poffset= 0#phase offset
    output = coeff*math.sin(omega*t + k*x + self.phase + poffset)

# %%
import driver

# %%
shapes = np.array([
            [6,4],
            [4,4],
            [4,1]])
dd = driver.Driver(shapes)

# %%
for i in range(dd.num_layers):
    dd.params[i]=np.random.random_sample(dd.params[i].shape)

# %%
dd.params
# Out:
# [array([[0.40048488, 0.49575324, 0.44744077, 0.4726787 ],
#         [0.01958386, 0.02149671, 0.81065192, 0.46219371],
#         [0.3775914 , 0.08642095, 0.21868983, 0.64353699],
#         [0.0193075 , 0.17815555, 0.81520946, 0.7519481 ],
#         [0.47212776, 0.66199601, 0.67471745, 0.34251105],
#         [0.15540023, 0.78822742, 0.01964268, 0.92619882]]),
#  array([[0.87720353, 0.12748564, 0.88250994, 0.39391273],
#         [0.87216492, 0.54104191, 0.50646439, 0.15695317],
#         [0.23466855, 0.11780443, 0.11597918, 0.24742956],
#         [0.71345442, 0.25042697, 0.26316236, 0.40437202]]),
#  array([[0.55900205],
#         [0.71814086],
#         [0.04925797],
#         [0.92356499]])]

# %%
dd.params[2]

input_array = np.array([1,2,3,4,5,6])
dd.output(input_array)
# Out:
# (1,)
# 32.27349302706611

# %%
# input = np.array([[1,2,3,4]])
# layer = np.array(   [
#                     [1],
#                     [4],
#                     [2],
#                     [3]])
# print(input.shape)
# print(layer.shape)
# out = np.matmul(input,layer)
# out[0][0]

# %%
import json

# %%
with open('t100.json') as f:
    df = json.load(f)

# %%
x = df['data'][5]['x']
y = df['data'][5]['y']
# plt.plot(x,y)
k1=0.0126
k2=0.01375
k3=0.0149
force = [9.8*x for x in y]
rev1 = [math.sqrt(abs(x)/k1) for x in force]
rev2 = [math.sqrt(abs(x)/k2) for x in force]
rev3 = [math.sqrt(abs(x)/k3) for x in force]

plt.plot(x,rev1)
plt.plot(x,rev2)
plt.plot(x,rev3)

# %%
rpm = df['data'][2]['y']
rpm_hz = [x/60 for x in rpm]
plt.plot(x,rpm_hz)
